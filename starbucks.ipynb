# %% [markdown]
# # Analysis of Geographic and Demographic Data To Determine New Starbucks Location

# %% [markdown]
# We are looking to find the next location for a Starbucks Reserve Roastery. We'll investigate the demographics of various counties in the state of California, to determine potentially suitable locations.

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
from folium import Marker
from geopy.geocoders import Nominatim
from IPython.display import IFrame

# %%
# Load and preview Starbucks locations in California
starbucks_data = pd.read_csv("C:/Users/hzerr/geopan/Starbucks/data/starbucks_locations.csv")
starbucks_data.head()
# Out:
#    Store Number               Store Name  \
# 0  10429-100710       Palmdale & Hwy 395
# 1       635-352    Kanan & Thousand Oaks
# 2   74510-27669  Vons-Agoura Hills #2001
# 3  29839-255026    Target Anaheim T-0677
# 4  23463-230284   Safeway - Alameda 3281
#
#                                    Address          City  Longitude  Latitude
# 0             14136 US Hwy 395 Adelanto CA      Adelanto    -117.40     34.51
# 1                5827 Kanan Road Agoura CA        Agoura    -118.76     34.16
# 2           5671 Kanan Rd. Agoura Hills CA  Agoura Hills    -118.76     34.15
# 3  8148 E SANTA ANA CANYON ROAD AHAHEIM CA       AHAHEIM    -117.75     33.87
# 4               2600 5th Street Alameda CA       Alameda    -122.28     37.79

# %% [markdown]
# ### Exploratory Data Analysis

# %%
starbucks_data.isnull().sum()
# Out:
# Store Number    0
# Store Name      0
# Address         0
# City            0
# Longitude       5
# Latitude        5
# dtype: int64

# %%
starbucks_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2821 entries, 0 to 2820
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store Number  2821 non-null   object
#  1   Store Name    2821 non-null   object
#  2   Address       2821 non-null   object
#  3   City          2821 non-null   object
#  4   Longitude     2816 non-null   float64
#  5   Latitude      2816 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 132.4+ KB

# %% [markdown]
# There are 5 rows missing the longitude and latitude. All other columns contain all necessary data.

# %%
starbucks_data[starbucks_data.isnull().any(axis=1)]
# Out:
#      Store Number                Store Name  \
# 153      5406-945  2224 Shattuck - Berkeley
# 154       570-512                Solano Ave
# 155  17877-164526   Safeway - Berkeley #691
# 156  19864-202264         Telegraph & Ashby
# 157     9217-9253           2128 Oxford St.
#
#                                Address      City  Longitude  Latitude
# 153   2224 Shattuck Avenue Berkeley CA  Berkeley        NaN       NaN
# 154     1799 Solano Avenue Berkeley CA  Berkeley        NaN       NaN
# 155    1444 Shattuck Place Berkeley CA  Berkeley        NaN       NaN
# 156  3001 Telegraph Avenue Berkeley CA  Berkeley        NaN       NaN
# 157     2128 Oxford Street Berkeley CA  Berkeley        NaN       NaN

# %% [markdown]
# The stores with null values are located in Berkeley. Missing values for latitude and longitude will be filled in.

# %%
missing_data = starbucks_data[starbucks_data.isnull().any(axis=1)]

# %% [markdown]
# ### Data Cleaning

# %%
# Instantiate geolocator
geolocator = Nominatim(user_agent="zhogan")

for idx, row in missing_data.iterrows():
    location = geolocator.geocode(row["Address"])

    if location:
        # Update longitude and latitude in the DataFrame
        missing_data.loc[idx, 'Longitude'] = [location.longitude]
        missing_data.loc[idx, 'Latitude'] = [location.latitude]
    else:
        print(f"Latitude and longitude for {missing_data.iloc[addy]['Address']} not found")

missing_data
# Out:
#      Store Number                Store Name  \
# 153      5406-945  2224 Shattuck - Berkeley
# 154       570-512                Solano Ave
# 155  17877-164526   Safeway - Berkeley #691
# 156  19864-202264         Telegraph & Ashby
# 157     9217-9253           2128 Oxford St.
#
#                                Address      City   Longitude   Latitude
# 153   2224 Shattuck Avenue Berkeley CA  Berkeley -122.268230  37.868839
# 154     1799 Solano Avenue Berkeley CA  Berkeley -122.280013  37.891477
# 155    1444 Shattuck Place Berkeley CA  Berkeley -122.269679  37.880907
# 156  3001 Telegraph Avenue Berkeley CA  Berkeley -122.259406  37.855903
# 157     2128 Oxford Street Berkeley CA  Berkeley -122.266095  37.870253

# %%
# Update original DataFrame with new values for latitude and longitude
starbucks_data.update(missing_data)

starbucks_data[starbucks_data["City"]=="Berkeley"]
# Out:
#      Store Number                Store Name  \
# 153      5406-945  2224 Shattuck - Berkeley
# 154       570-512                Solano Ave
# 155  17877-164526   Safeway - Berkeley #691
# 156  19864-202264         Telegraph & Ashby
# 157     9217-9253           2128 Oxford St.
#
#                                Address      City   Longitude   Latitude
# 153   2224 Shattuck Avenue Berkeley CA  Berkeley -122.268230  37.868839
# 154     1799 Solano Avenue Berkeley CA  Berkeley -122.280013  37.891477
# 155    1444 Shattuck Place Berkeley CA  Berkeley -122.269679  37.880907
# 156  3001 Telegraph Avenue Berkeley CA  Berkeley -122.259406  37.855903
# 157     2128 Oxford Street Berkeley CA  Berkeley -122.266095  37.870253

# %%
starbucks_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2821 entries, 0 to 2820
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store Number  2821 non-null   object
#  1   Store Name    2821 non-null   object
#  2   Address       2821 non-null   object
#  3   City          2821 non-null   object
#  4   Longitude     2821 non-null   float64
#  5   Latitude      2821 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 132.4+ KB

# %% [markdown]
# Now all of the Starbucks data is complete.

# %% [markdown]
# ### Data Visualization

# %%
# Create a base map
map1 = folium.Map(location=[37.88,-122.26], zoom_start=13)

# Add a marker for each Berkeley location
for idx, row in starbucks_data.iterrows():
    Marker(location=[starbucks_data.iloc[idx]['Latitude'], starbucks_data.iloc[idx]['Longitude']]).add_to(map1)

map1.save("map1.png")
map1.save("map1.html")

# Display the HTML map using IFrame
IFrame(src="map1.html", width=900, height=600)
# Out:
#         <iframe
#             width="900"
#             height="600"
#             src="map1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# All Berkeley locations appear to be correct. Next, a new file will be read in that contains the county boundaries for California.

# %%
CA_counties = gpd.read_file("C:/Users/hzerr/geopan/Starbucks/data/CA_county_boundaries/CA_county_boundaries/CA_county_boundaries.shp")
CA_counties = CA_counties.to_crs(epsg=4326)
CA_counties.head()
# Out:
#    GEOID                  name    area_sqkm  \
# 0   6091         Sierra County  2491.995494
# 1   6067     Sacramento County  2575.258262
# 2   6083  Santa Barbara County  9813.817958
# 3   6009      Calaveras County  2685.626726
# 4   6111        Ventura County  5719.321379
#
#                                             geometry
# 0  POLYGON ((-120.65560 39.69357, -120.65554 39.6...
# 1  POLYGON ((-121.18858 38.71431, -121.18732 38.7...
# 2  MULTIPOLYGON (((-120.58191 34.09856, -120.5822...
# 3  POLYGON ((-120.63095 38.34111, -120.63058 38.3...
# 4  MULTIPOLYGON (((-119.63631 33.27304, -119.6360...

# %% [markdown]
# ### Data Mining

# %% [markdown]
# Next, data frames will be created that contain population, income and age.

# %%
CA_pop = pd.read_csv("C:/Users/hzerr/geopan/Starbucks/data/CA_county_population.csv", index_col="GEOID")
CA_high_earners = pd.read_csv("C:/Users/hzerr/geopan/Starbucks/data/CA_county_high_earners.csv", index_col="GEOID")
CA_median_age = pd.read_csv("C:/Users/hzerr/geopan/Starbucks/data/CA_county_median_age.csv", index_col="GEOID")

# %%
CA_pop.head()
# Out:
#        population
# GEOID
# 6001      1666753
# 6003         1101
# 6005        39383
# 6007       231256
# 6009        45602

# %%
CA_high_earners.head()
# Out:
#        high_earners
# GEOID
# 6001         145696
# 6003             30
# 6005           1220
# 6007           6860
# 6009           2046

# %% [markdown]
# The high_earners data frame contains the number of people in each county who earn $150,000 or more annually.

# %%
CA_median_age.head()
# Out:
#        median_age
# GEOID
# 6001         37.3
# 6003         44.9
# 6005         50.6
# 6007         36.9
# 6009         51.6

# %%
# Join all data frames
CA_counties = CA_counties.merge(CA_pop, on="GEOID").merge(CA_high_earners, on="GEOID").merge(CA_median_age, on="GEOID")

# %%
CA_counties.head()
# Out:
#    GEOID                  name    area_sqkm  \
# 0   6091         Sierra County  2491.995494
# 1   6067     Sacramento County  2575.258262
# 2   6083  Santa Barbara County  9813.817958
# 3   6009      Calaveras County  2685.626726
# 4   6111        Ventura County  5719.321379
#
#                                             geometry  population  \
# 0  POLYGON ((-120.65560 39.69357, -120.65554 39.6...        2987
# 1  POLYGON ((-121.18858 38.71431, -121.18732 38.7...     1540975
# 2  MULTIPOLYGON (((-120.58191 34.09856, -120.5822...      446527
# 3  POLYGON ((-120.63095 38.34111, -120.63058 38.3...       45602
# 4  MULTIPOLYGON (((-119.63631 33.27304, -119.6360...      850967
#
#    high_earners  median_age
# 0           111        55.0
# 1         65768        35.9
# 2         25231        33.7
# 3          2046        51.6
# 4         57121        37.5

# %%
# Create a density column
CA_counties["density"] = round(CA_counties["population"] / CA_counties["area_sqkm"], 2)

# %%
CA_counties["density"].head()
# Out:
# 0      1.20
# 1    598.38
# 2     45.50
# 3     16.98
# 4    148.79
# Name: density, dtype: float64

# %% [markdown]
# Next, counties selected will be places that have a population density of at least 300 per square kilometer, a median age less than 40 and at least 200,000 high income earners.

# %%
candidate_counties = CA_counties[(CA_counties["density"] >= 200) & (CA_counties["median_age"] < 40) & (CA_counties["high_earners"] >= 100000)]

# %%
len(candidate_counties)
# Out:
# 7

# %% [markdown]
# There are 7 potential counties for the new Starbucks Reserve Roastery location.

# %%
# Convert Starbucks data frame to GDF before joining
starbucks_gdf = gpd.GeoDataFrame(starbucks_data, geometry=gpd.points_from_xy(starbucks_data.Longitude, starbucks_data.Latitude))
starbucks_gdf = starbucks_gdf.set_crs(epsg=4326)

candidate_stores = gpd.sjoin(starbucks_gdf, candidate_counties, how="inner")

# %%
candidate_stores
# Out:
#       Store Number                       Store Name  \
# 1          635-352            Kanan & Thousand Oaks
# 2      74510-27669          Vons-Agoura Hills #2001
# 3     29839-255026            Target Anaheim T-0677
# 4     23463-230284           Safeway - Alameda 3281
# 5       6479-62999           Park & Central Alameda
# ...            ...                              ...
# 2806    9384-94268                  Canoga & Oxnard
# 2807  18869-179006           Mulholland & Calabasas
# 2808  11603-104000          Topanga Canyon & Dumetz
# 2809     5450-1464  Yorba Linda & Village Center Dr
# 2810    6488-53879        Yorba Linda & Valley View
#
#                                                 Address            City  \
# 1                             5827 Kanan Road Agoura CA          Agoura
# 2                        5671 Kanan Rd. Agoura Hills CA    Agoura Hills
# 3               8148 E SANTA ANA CANYON ROAD AHAHEIM CA         AHAHEIM
# 4                            2600 5th Street Alameda CA         Alameda
# 5                           1364 Park Street Alameda CA         Alameda
# ...                                                 ...             ...
# 2806           5960 N. Canoga Ave, #1 Woodland Hills CA  Woodland Hills
# 2807           23335 Mulholland Drive Woodland Hills CA  Woodland Hills
# 2808         4900 Topanga Canyon Blvd Woodland Hills CA  Woodland Hills
# 2809  20355 Yorba Linda Blvd, Valley View Shopping C...     Yorba Linda
# 2810         17474 Yorba Linda Boulevard Yorba Linda CA     Yorba Linda
#
#       Longitude  Latitude                     geometry  index_right  GEOID  \
# 1       -118.76     34.16  POINT (-118.76000 34.16000)            5   6037
# 2       -118.76     34.15  POINT (-118.76000 34.15000)            5   6037
# 3       -117.75     33.87  POINT (-117.75000 33.87000)           47   6059
# 4       -122.28     37.79  POINT (-122.28000 37.79000)           41   6001
# 5       -122.24     37.76  POINT (-122.24000 37.76000)           41   6001
# ...         ...       ...                          ...          ...    ...
# 2806    -118.60     34.18  POINT (-118.60000 34.18000)            5   6037
# 2807    -118.63     34.16  POINT (-118.63000 34.16000)            5   6037
# 2808    -118.61     34.16  POINT (-118.61000 34.16000)            5   6037
# 2809    -117.78     33.89  POINT (-117.78000 33.89000)           47   6059
# 2810    -117.83     33.89  POINT (-117.83000 33.89000)           47   6059
#
#                     name     area_sqkm  population  high_earners  median_age  \
# 1     Los Angeles County  12305.376879    10105518        501413        36.0
# 2     Los Angeles County  12305.376879    10105518        501413        36.0
# 3          Orange County   2455.308632     3185968        233459        37.5
# 4         Alameda County   2127.222169     1666753        145696        37.3
# 5         Alameda County   2127.222169     1666753        145696        37.3
# ...                  ...           ...         ...           ...         ...
# 2806  Los Angeles County  12305.376879    10105518        501413        36.0
# 2807  Los Angeles County  12305.376879    10105518        501413        36.0
# 2808  Los Angeles County  12305.376879    10105518        501413        36.0
# 2809       Orange County   2455.308632     3185968        233459        37.5
# 2810       Orange County   2455.308632     3185968        233459        37.5
#
#       density
# 1      821.23
# 2      821.23
# 3     1297.58
# 4      783.53
# 5      783.53
# ...       ...
# 2806   821.23
# 2807   821.23
# 2808   821.23
# 2809  1297.58
# 2810  1297.58
#
# [1719 rows x 15 columns]

# %% [markdown]
# There are 1,719 stores in counties that meet the criteria for a new store.

# %% [markdown]
# ### Conclusion

# %%
map2 = folium.Map(location=[37,-120], zoom_start=6)

# Show selected store locations
for i, j in candidate_stores.iterrows():
    Marker(
        location=[j["Latitude"], j["Longitude"]],
        popup=f'{j["Address"]}'
    ).add_to(map2)

map2.save("map2.png")
map2.save("map2.html")

# Display the HTML map using IFrame
IFrame(src="map1.html", width=900, height=600)
# Out:
#         <iframe
#             width="900"
#             height="600"
#             src="map1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# On the map, 1,719 locations meet the requirements for a new store based on income, age and population density. Clicking on each marker allows us to see the actual store address.
